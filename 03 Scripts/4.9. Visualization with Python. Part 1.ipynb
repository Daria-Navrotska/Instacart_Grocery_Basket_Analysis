# %%
#importing libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\ZenBook\Instacart Basket Analysis_30.09.2025'

# %%
df_customers = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'))

# %%
df_customers.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
#check the shape of the database
df_customers.shape
# Out:
# (206209, 10)

# %%
df_customers.describe()
# Out:
#              user_id            Age   n_dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %% [markdown]
# # Wrangle the data so that it follows consistent logic; for example, rename columns with illogical names and drop columns that don’t add anything to your analysis.

# %%
# check
df_customers
# Out:
#         user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 0         26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1         33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2         65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3        125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4        130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# ...         ...        ...       ...     ...             ...  ...         ...
# 206204   168073       Lisa      Case  Female  North Carolina   44    4/1/2020
# 206205    49635     Jeremy   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902      Doris  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095       Rose   Rollins  Female      California   27    4/1/2020
# 206208    80148    Cynthia     Noble  Female        New York   55    4/1/2020
#
# ...

# %%
#rename'First Name'
df_customers.rename(columns = {'First Name' : 'first name'}, inplace = True)

# %%
#rename'Surnam'
df_customers.rename(columns = {'Surnam' : 'surname'}, inplace = True)

# %%
#rename'Gender'
df_customers.rename(columns = {'Gender' : 'gender'}, inplace = True)

# %%
#rename'STATE'
df_customers.rename(columns = {'STATE' : 'state'}, inplace = True)

# %%
#rename'Age'
df_customers.rename(columns = {'Age' : 'age'}, inplace = True)

# %%
#rename 'fam_status'
df_customers.rename(columns = {'fam_status' : 'status'}, inplace = True)

# %%
# check
df_customers.head()
# Out:
#    user_id first name   surname  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants   status  income
# 0             3  married  165665
# 1             0   single   59285
# 2             2  married   99568
# 3             0   single   42049
# 4             1  married   40374

# %% [markdown]
# # Complete the fundamental data quality and consistency checks you’ve learned throughout this Achievement; for example, check for and address missing values and duplicates, and convert any mixed-type data.

# %%
# check for missing values
df_customers.isnull().sum()
# Out:
# user_id             0
# first name      11259
# surname             0
# gender              0
# state               0
# age                 0
# date_joined         0
# n_dependants        0
# status              0
# income              0
# dtype: int64

# %% [markdown]
# As there are a lot of data missing in the column 'first name', I decided to delete it.

# %%
df_customers = df_customers.drop(columns=["first name"])

# %%
df_customers = df_customers.drop(columns=["surname"])

# %%
# check
df_customers.head()
# Out:
#    user_id  gender       state  age date_joined  n_dependants   status  income
# 0    26711  Female    Missouri   48    1/1/2017             3  married  165665
# 1    33890  Female  New Mexico   36    1/1/2017             0   single   59285
# 2    65803    Male       Idaho   35    1/1/2017             2  married   99568
# 3   125935  Female        Iowa   40    1/1/2017             0   single   42049
# 4   130797  Female    Maryland   26    1/1/2017             1  married   40374

# %%
# check for missing values
df_customers.isnull().sum()
# Out:
# user_id         0
# gender          0
# state           0
# age             0
# date_joined     0
# n_dependants    0
# status          0
# income          0
# dtype: int64

# %% [markdown]
# No missing values founded.

# %%
# cheking for duplicate 
df_dups= df_customers[df_customers.duplicated()]

# %%
#check the output
df_dups
# Out:
# Empty DataFrame
# Columns: [user_id, gender, state, age, date_joined, n_dependants, status, income]
# Index: []

# %% [markdown]
# There are no duplicates founded.

# %%
#checking for mixed-type data
df_customers.dtypes
# Out:
# user_id          int64
# gender          object
# state           object
# age              int64
# date_joined     object
# n_dependants     int64
# status          object
# income           int64
# dtype: object

# %% [markdown]
# No mixed data type was found in the customers data frame.

# %% [markdown]
# # Combine your customer data with the rest of your prepared Instacart data. (Hint: Make sure the key columns are the same data type!)

# %%
df_ords_prods_merge_grouped = pd.read_parquet(r'C:\Users\ZenBook\Instacart Basket Analysis_30.09.2025\02 Data\Prepared Data\ords_prods_merge_grouped.parquet')

# %%
df_ords_prods_merge_grouped.shape
# Out:
# (32406041, 27)

# %%
df_ords_prods_merge_grouped.describe()
# Out:
#          product_id      aisle_id  department_id        prices      order_id  \
# count  3.240604e+07  3.240604e+07   3.240604e+07  3.240604e+07  3.240604e+07
# mean   2.559895e+04  7.119773e+01   9.919923e+00  1.198004e+01  1.710745e+06
# std    1.408389e+04  3.821182e+01   6.281418e+00  4.956464e+02  9.872986e+05
# min    1.000000e+00  1.000000e+00   1.000000e+00  1.000000e+00  2.000000e+00
# 25%    1.354400e+04  3.100000e+01   4.000000e+00  4.200000e+00  8.559480e+05
# 50%    2.530500e+04  8.300000e+01   9.000000e+00  7.400000e+00  1.711050e+06
# 75%    3.794700e+04  1.070000e+02   1.600000e+01  1.130000e+01  2.565497e+06
# max    4.968800e+04  1.340000e+02   2.100000e+01  9.999900e+04  3.421083e+06
#
#             user_id  order_number     order_dow  order_hour_of_day  \
# count  3.240604e+07  3.240604e+07  3.240604e+07       3.240604e+07
# mean   1.029371e+05  1.714223e+01  2.738862e+00       1.342515e+01
# std    5.946610e+04  1.753527e+01  2.090074e+00       4.246382e+00
# ...

# %%
df_ords_prods_merge_grouped.columns
# Out:
# Index(['product_id', 'product_name', 'aisle_id', 'department_id', 'prices',
#        'order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order', 'first_order',
#        'add_to_cart_order', 'reordered', '_merge', 'price_range_loc',
#        'busiest_day', 'busiest_days', 'busiest_period_of_day', 'max_order',
#        'loyalty_flag', 'spend_by_user_avg', 'spending_flag',
#        'regul_used_median', 'regul_user_median', 'order_frequency_flag'],
#       dtype='object')

# %% [markdown]
# combining will be done by the user_id column as it is common for two databases

# %%
#Drop the '_merge' column from the 'ords_prod_merge_grouped'
df_ords_prods_merge_grouped = df_ords_prods_merge_grouped.drop('_merge', axis=1)

# %%
# check
df_ords_prods_merge_grouped.columns
# Out:
# Index(['product_id', 'product_name', 'aisle_id', 'department_id', 'prices',
#        'order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order', 'first_order',
#        'add_to_cart_order', 'reordered', 'price_range_loc', 'busiest_day',
#        'busiest_days', 'busiest_period_of_day', 'max_order', 'loyalty_flag',
#        'spend_by_user_avg', 'spending_flag', 'regul_used_median',
#        'regul_user_median', 'order_frequency_flag'],
#       dtype='object')

# %%
df_ords_prods_merge_grouped.shape
# Out:
# (32406041, 26)

# %%
#Merge (join) ords_prods_merge_grouped with df_customers via user_id

df_ords_prods_merge_custs = df_ords_prods_merge_grouped.merge(df_customers, on="user_id", how="inner", sort=False)

# %%
# check the shape of merged df
df_ords_prods_merge_custs.shape
# Out:
# (32406041, 33)

# %%
df_ords_prods_merge_custs.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  order_dow  ...  \
# 0   3139998      138    prior            28          6  ...
# 1   1977647      138    prior            30          6  ...
# 2    389851      709    prior             2          0  ...
# 3    652770      764    prior             1          3  ...
# 4   1813452      764    prior             3          4  ...
#
#    regul_used_median  regul_user_median  order_frequency_flag  gender  \
# 0                8.0                8.0     Frequent customer    Male
# ...

# %%
# exporting merged df 
df_ords_prods_merge_custs.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'df_ords_prods_merge_custs.pkl'))
